# %%
import openai
from arguments import get_config
from interfaces import setup_LMP
from visualizers import ValueMapVisualizer
from envs.rlbench_env import VoxPoserRLBench
from utils import set_lmp_objects
import numpy as np
from rlbench import tasks

openai.api_key = ""  # set your API key here
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Setup

# %%
config = get_config('rlbench')
# uncomment this if you'd like to change the language model (e.g., for faster speed or lower cost)
# for lmp_name, cfg in config['lmp_config']['lmps'].items():
#     cfg['model'] = 'gpt-3.5-turbo'

# initialize env and voxposer ui
visualizer = ValueMapVisualizer(config['visualizer'])
env = VoxPoserRLBench(visualizer=visualizer)
lmps, lmp_env = setup_LMP(env, config, debug=False)
voxposer_ui = lmps['plan_ui']
# Out:
# ##################################################
# ## voxel resolution: [0.0105 0.0131 0.01  ]
# ##################################################

# %% [markdown]
# ## Playground
#
# By default we use one of the instructions that come with each task. However, you may treat each task as simply a scene initialization from RLBench, and feel free to try any task you can come up with for the scene.
#
# Note:
# - Whether an instruction can be executed or not depends on 1) whether relevant objects are available, and 2) capabilities of the overall algorithm.
# - Each execution may produce one or more visualizations. You may view them in "./visualizations/" folder.
# - The prompts are adapted with minimal change from the real-world environment in the VoxPoser paper. If a task failure is due to incorrect code generated by the LLM, feel free to modify the relevant prompt in "./prompts/" folder.
# - You may view the reward by printing "env.latest_reward". These are computed by RLBench for each task.
# - To inspect in viewer without performing any action, you may call "env.rlbench_env._scene.step()" in a loop.

# %%
# # uncomment this to show all available tasks in rlbench
# # NOTE: in order to run a new task, you need to add the list of objects (and their corresponding env names) to the "task_object_names.json" file. See README for more details.
# print([task for task in dir(tasks) if task[0].isupper() and not '_' in task])

# %%
# below are the tasks that have object names added to the "task_object_names.json" file
# uncomment one to use
env.load_task(tasks.PutRubbishInBin)
# env.load_task(tasks.LampOff)
# env.load_task(tasks.OpenWineBottle)
# env.load_task(tasks.PushButton)
# env.load_task(tasks.TakeOffWeighingScales)
# env.load_task(tasks.MeatOffGrill)
# env.load_task(tasks.SlideBlockToTarget)
# env.load_task(tasks.TakeLidOffSaucepan)
# env.load_task(tasks.TakeUmbrellaOutOfUmbrellaStand)

descriptions, obs = env.reset()
set_lmp_objects(lmps, env.get_object_names())  # set the object names to be used by voxposer

# %%
instruction = np.random.choice(descriptions)
voxposer_ui(instruction)
# Out:
# *** OpenAI API call took 3.18s ***
# ########################################
# ## "planner" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: chuck way any rubbish on the table rubbish.
# composer("grasp the rubbish")
# composer("back to default pose")
# composer("move to the top of the bin")
# composer("open gripper")
# composer("back to default pose")
# # done
#
#
# *** OpenAI API call took 5.69s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: grasp the rubbish.
# movable = parse_query_obj('gripper')
# affordance_map = get_affordance_map('a point at the center of the rubbish')
# gripper_map = get_gripper_map('open everywhere except 1cm around the rubbish')
# execute(movable, affordance_map=affordance_map, gripper_map=gripper_map)
#
#
# *** OpenAI API call took 1.40s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 6.09s ***
# ########################################
# ## "get_affordance_map" generated code
# ########################################
# # Query: a point at the center of the rubbish.
# affordance_map = get_empty_affordance_map()
# rubbish = parse_query_obj('rubbish')
# x, y, z = rubbish.position
# affordance_map[x, y, z] = 1
# ret_val = affordance_map
#
#
# *** OpenAI API call took 5.11s ***
# ########################################
# ## "get_gripper_map" generated code
# ########################################
# # Query: open everywhere except 1cm around the rubbish.
# gripper_map = get_empty_gripper_map()
# # open everywhere
# gripper_map[:, :, :] = 1
# # close when 1cm around the rubbish
# rubbish = parse_query_obj('rubbish')
# set_voxel_by_radius(gripper_map, rubbish.position, radius_cm=1, value=0)
# ret_val = gripper_map
#
#
# *** OpenAI API call took 1.34s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: rubbish.
# rubbish = detect('rubbish')
# ret_val = rubbish
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: rubbish.
# rubbish = detect('rubbish')
# ret_val = rubbish
#
#
# [planners.py | 14:24:44.204] start
# [planners.py | 14:24:44.318] start optimizing, start_pos: [52 49 71]
# [planners.py | 14:24:44.349] optimization finished; path length: 36
# [planners.py | 14:24:44.361] after postprocessing, path length: 36
# [planners.py | 14:24:44.361] last waypoint: [54.10220215 30.08740824  1.        ]
# [interfaces.py | 14:24:44] planner time: 0.159s
# [interfaces.py | 14:24:44] overwriting gripper to less common value for the last waypoint
# ** saving visualization to ./visualizations/14:24:44.html ...
# ** saving visualization to ./visualizations/latest.html ...
# ** save to ./visualizations/14:24:44.html
# [interfaces.py | 14:24:44] start executing path via controller (38 waypoints)
# [interfaces.py | 14:24:44] completed waypoint 1 (wp: [0.286 0.005 1.469], actual: [0.286 0.004 1.469], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.753)
# [interfaces.py | 14:24:45] completed waypoint 2 (wp: [ 0.29  -0.031  1.449], actual: [ 0.29  -0.031  1.449], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.723)
# [interfaces.py | 14:24:45] completed waypoint 3 (wp: [ 0.293 -0.064  1.429], actual: [ 0.293 -0.063  1.428], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.694)
# [interfaces.py | 14:24:45] completed waypoint 4 (wp: [ 0.296 -0.095  1.409], actual: [ 0.296 -0.094  1.408], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.667)
# [interfaces.py | 14:24:45] completed waypoint 5 (wp: [ 0.297 -0.123  1.388], actual: [ 0.298 -0.122  1.388], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.64)
# [interfaces.py | 14:24:46] completed waypoint 6 (wp: [ 0.299 -0.148  1.368], actual: [ 0.299 -0.148  1.368], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.616)
# [interfaces.py | 14:24:46] completed waypoint 7 (wp: [ 0.299 -0.172  1.348], actual: [ 0.299 -0.171  1.348], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.592)
# [interfaces.py | 14:24:46] completed waypoint 8 (wp: [ 0.3   -0.192  1.328], actual: [ 0.3   -0.192  1.327], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.569)
# [interfaces.py | 14:24:46] completed waypoint 9 (wp: [ 0.3   -0.211  1.308], actual: [ 0.3   -0.21   1.308], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.548)
# [interfaces.py | 14:24:46] completed waypoint 10 (wp: [ 0.299 -0.226  1.287], actual: [ 0.299 -0.225  1.288], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.527)
# [interfaces.py | 14:24:47] completed waypoint 11 (wp: [ 0.298 -0.245  1.257], actual: [ 0.298 -0.244  1.257], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.496)
# [interfaces.py | 14:24:47] completed waypoint 12 (wp: [ 0.298 -0.254  1.237], actual: [ 0.298 -0.253  1.237], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.475)
# [interfaces.py | 14:24:47] completed waypoint 13 (wp: [ 0.298 -0.26   1.217], actual: [ 0.298 -0.26   1.216], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.454)
# [interfaces.py | 14:24:47] completed waypoint 14 (wp: [ 0.298 -0.263  1.196], actual: [ 0.298 -0.263  1.196], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.434)
# [interfaces.py | 14:24:48] completed waypoint 15 (wp: [ 0.298 -0.265  1.176], actual: [ 0.298 -0.265  1.176], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.414)
# [interfaces.py | 14:24:48] completed waypoint 16 (wp: [ 0.298 -0.264  1.156], actual: [ 0.298 -0.263  1.156], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.394)
# [interfaces.py | 14:24:48] completed waypoint 17 (wp: [ 0.298 -0.262  1.136], actual: [ 0.298 -0.262  1.136], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.374)
# [interfaces.py | 14:24:48] completed waypoint 18 (wp: [ 0.298 -0.26   1.116], actual: [ 0.298 -0.26   1.115], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.353)
# [interfaces.py | 14:24:48] completed waypoint 19 (wp: [ 0.298 -0.258  1.095], actual: [ 0.298 -0.258  1.095], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.333)
# [interfaces.py | 14:24:49] completed waypoint 20 (wp: [ 0.299 -0.258  1.075], actual: [ 0.298 -0.258  1.076], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.314)
# [interfaces.py | 14:24:49] completed waypoint 21 (wp: [ 0.299 -0.259  1.055], actual: [ 0.298 -0.259  1.055], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.293)
# [interfaces.py | 14:24:49] completed waypoint 22 (wp: [ 0.298 -0.26   1.035], actual: [ 0.298 -0.26   1.036], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.274)
# [interfaces.py | 14:24:49] completed waypoint 23 (wp: [ 0.298 -0.262  1.015], actual: [ 0.297 -0.262  1.014], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.252)
# [interfaces.py | 14:24:49] completed waypoint 24 (wp: [ 0.296 -0.263  0.994], actual: [ 0.296 -0.263  0.994], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.232)
# [interfaces.py | 14:24:50] completed waypoint 25 (wp: [ 0.295 -0.265  0.974], actual: [ 0.295 -0.265  0.974], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.212)
# [interfaces.py | 14:24:50] completed waypoint 26 (wp: [ 0.294 -0.267  0.954], actual: [ 0.294 -0.267  0.954], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.192)
# [interfaces.py | 14:24:50] completed waypoint 27 (wp: [ 0.293 -0.268  0.944], actual: [ 0.293 -0.268  0.944], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.182)
# [interfaces.py | 14:24:50] completed waypoint 28 (wp: [ 0.292 -0.27   0.924], actual: [ 0.292 -0.27   0.924], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.162)
# [interfaces.py | 14:24:51] completed waypoint 29 (wp: [ 0.291 -0.272  0.904], actual: [ 0.291 -0.271  0.903], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.142)
# [interfaces.py | 14:24:51] completed waypoint 30 (wp: [ 0.29  -0.273  0.883], actual: [ 0.29  -0.272  0.883], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.122)
# [interfaces.py | 14:24:51] completed waypoint 31 (wp: [ 0.29  -0.273  0.863], actual: [ 0.289 -0.272  0.863], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.103)
# [interfaces.py | 14:24:51] completed waypoint 32 (wp: [ 0.29  -0.272  0.843], actual: [ 0.29  -0.272  0.843], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.083)
# [interfaces.py | 14:24:51] completed waypoint 33 (wp: [ 0.291 -0.27   0.823], actual: [ 0.291 -0.27   0.823], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.063)
# [interfaces.py | 14:24:52] completed waypoint 34 (wp: [ 0.293 -0.267  0.803], actual: [ 0.292 -0.267  0.803], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.042)
# [interfaces.py | 14:24:52] completed waypoint 35 (wp: [ 0.295 -0.263  0.782], actual: [ 0.295 -0.263  0.782], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.021)
# [interfaces.py | 14:24:52] skip waypoint 36 because it is moving in opposite direction of the final target
# [interfaces.py | 14:24:52] skip waypoint 37 because it is moving in opposite direction of the final target
# [interfaces.py | 14:24:52] completed waypoint 38 (wp: [ 0.299 -0.257  0.762], actual: [ 0.298 -0.257  0.762], target: [ 0.299 -0.257  0.762], start: [0.286 0.005 1.469], dist2target: 0.0)
# [interfaces.py | 14:24:52] reached target; terminating
# [interfaces.py | 14:24:52] finished executing path via controller
# *** OpenAI API call took 1.61s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: back to default pose.
# reset_to_default_pose()
#
#
# *** OpenAI API call took 3.45s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: move to the top of the bin.
# movable = parse_query_obj('gripper')
# affordance_map = get_affordance_map('a point 10cm above the bin')
# execute(movable, affordance_map=affordance_map)
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 9.18s ***
# ########################################
# ## "get_affordance_map" generated code
# ########################################
# # Query: a point 10cm above the bin.
# affordance_map = get_empty_affordance_map()
# bin = parse_query_obj('bin')
# (min_x, min_y, min_z), (max_x, max_y, max_z) = bin.aabb
# center_x, center_y, center_z = bin.position
# # 10cm above so we add to z-axis
# x = center_x
# y = center_y
# z = max_z + cm2index(10, 'z')
# affordance_map[x, y, z] = 1
# ret_val = affordance_map
#
#
# *** OpenAI API call took 1.57s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: bin.
# bin = detect('bin')
# ret_val = bin
#
#
# [planners.py | 14:25:10.812] start
# [planners.py | 14:25:10.899] start optimizing, start_pos: [52 49 71]
# [planners.py | 14:25:10.916] optimization finished; path length: 22
# [planners.py | 14:25:10.918] after postprocessing, path length: 23
# [planners.py | 14:25:10.918] last waypoint: [63. 71. 29.]
# [interfaces.py | 14:25:10] planner time: 0.108s
# ** saving visualization to ./visualizations/14:25:10.html ...
# ** saving visualization to ./visualizations/latest.html ...
# ** save to ./visualizations/14:25:10.html
# [interfaces.py | 14:25:11] start executing path via controller (25 waypoints)
# [interfaces.py | 14:25:11] completed waypoint 1 (wp: [ 0.271 -0.012  1.469], actual: [ 0.272 -0.012  1.469], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.531)
# [interfaces.py | 14:25:11] completed waypoint 2 (wp: [0.301 0.018 1.449], actual: [0.3   0.017 1.449], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.493)
# [interfaces.py | 14:25:11] completed waypoint 3 (wp: [0.325 0.047 1.429], actual: [0.325 0.046 1.429], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.457)
# [interfaces.py | 14:25:11] completed waypoint 4 (wp: [0.346 0.076 1.409], actual: [0.345 0.076 1.408], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.422)
# [interfaces.py | 14:25:12] completed waypoint 5 (wp: [0.362 0.105 1.388], actual: [0.361 0.103 1.389], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.39)
# [interfaces.py | 14:25:12] completed waypoint 6 (wp: [0.374 0.132 1.368], actual: [0.374 0.131 1.368], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.358)
# [interfaces.py | 14:25:12] completed waypoint 7 (wp: [0.384 0.158 1.348], actual: [0.384 0.157 1.348], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.329)
# [interfaces.py | 14:25:12] completed waypoint 8 (wp: [0.39  0.183 1.328], actual: [0.39  0.182 1.327], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.3)
# [interfaces.py | 14:25:12] completed waypoint 9 (wp: [0.395 0.206 1.308], actual: [0.395 0.205 1.307], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.274)
# [interfaces.py | 14:25:12] completed waypoint 10 (wp: [0.397 0.227 1.287], actual: [0.397 0.226 1.287], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.249)
# [interfaces.py | 14:25:13] completed waypoint 11 (wp: [0.399 0.253 1.257], actual: [0.399 0.253 1.256], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.214)
# [interfaces.py | 14:25:13] completed waypoint 12 (wp: [0.398 0.266 1.237], actual: [0.398 0.266 1.237], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.193)
# [interfaces.py | 14:25:13] completed waypoint 13 (wp: [0.397 0.272 1.227], actual: [0.397 0.271 1.226], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.182)
# [interfaces.py | 14:25:13] completed waypoint 14 (wp: [0.396 0.281 1.207], actual: [0.396 0.28  1.207], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.162)
# [interfaces.py | 14:25:13] completed waypoint 15 (wp: [0.394 0.287 1.186], actual: [0.394 0.287 1.186], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.141)
# [interfaces.py | 14:25:13] completed waypoint 16 (wp: [0.391 0.291 1.166], actual: [0.391 0.291 1.166], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.122)
# [interfaces.py | 14:25:14] completed waypoint 17 (wp: [0.39  0.294 1.146], actual: [0.39  0.293 1.146], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.101)
# [interfaces.py | 14:25:14] completed waypoint 18 (wp: [0.389 0.294 1.126], actual: [0.389 0.294 1.125], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.081)
# [interfaces.py | 14:25:14] completed waypoint 19 (wp: [0.389 0.292 1.106], actual: [0.389 0.292 1.105], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.061)
# [interfaces.py | 14:25:14] completed waypoint 20 (wp: [0.39  0.288 1.085], actual: [0.39  0.288 1.085], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.04)
# [interfaces.py | 14:25:14] completed waypoint 21 (wp: [0.394 0.282 1.065], actual: [0.393 0.282 1.066], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.021)
# [interfaces.py | 14:25:14] skip waypoint 22 because it is moving in opposite direction of the final target
# [interfaces.py | 14:25:14] skip waypoint 23 because it is moving in opposite direction of the final target
# [interfaces.py | 14:25:14] skip waypoint 24 because it is moving in opposite direction of the final target
# [interfaces.py | 14:25:14] completed waypoint 25 (wp: [0.393 0.284 1.045], actual: [0.393 0.284 1.045], target: [0.393 0.284 1.045], start: [ 0.271 -0.012  1.469], dist2target: 0.001)
# [interfaces.py | 14:25:14] reached target; terminating
# [interfaces.py | 14:25:14] finished executing path via controller
# *** OpenAI API call took 3.52s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: open gripper.
# movable = parse_query_obj('gripper')
# gripper_map = get_gripper_map('open everywhere')
# execute(movable, gripper_map=gripper_map)
#
#
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "parse_query_obj" generated code
# ## context: "objects = ['bin', 'rubbish', 'tomato1', 'tomato2']"
# ########################################
# objects = ['bin', 'rubbish', 'tomato1', 'tomato2']
# # Query: gripper.
# gripper = detect('gripper')
# ret_val = gripper
#
#
# *** OpenAI API call took 3.37s ***
# ########################################
# ## "get_gripper_map" generated code
# ########################################
# # Query: open everywhere.
# gripper_map = get_empty_gripper_map()
# # open everywhere
# gripper_map[:, :, :] = 1
# ret_val = gripper_map
#
#
# [interfaces.py | 14:25:21] finished executing path via controller
# (using cache) *** OpenAI API call took 0.00s ***
# ########################################
# ## "composer" generated code
# ########################################
# # Query: back to default pose.
# reset_to_default_pose()

# %%
env.rlbench_env.shutdown()
# Out:
# [CoppeliaSim:loadinfo]   done.
